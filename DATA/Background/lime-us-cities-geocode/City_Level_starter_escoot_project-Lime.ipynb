# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Import API key
import gmaps
# Google developer API key
from datetime import date
from config import gkey
from pprint import pprint
# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
#data provided by emily and harlan https://github.com/NABSA/gbfs/blob/master/systems.csv
bigdata_df=pd.read_csv("big_data.csv")
bigdata_df
# Out:
#     Country Code                Name               Location  \
# 0             AE      ADCB Bikeshare          Abu Dhabi, AE
# 1             AE         Careem BIKE              Dubai, AE
# 2             AR             Ecobici       Buenos Aires, AR
# 3             AR        MiBiciTuBici  Rosario, Santa Fe, AR
# 4             AR   Movo Buenos Aires       Buenos Aires, AR
# ..           ...                 ...                    ...
# 530           US        Wheels Miami              Miami, FL
# 531           US      Wheels Orlando            Orlando, FL
# 532           US    Wheels San Diego          San Diego, CA
# 533           US  Wheels Tallahassee        Tallahassee, FL
# 534           US        Wheels Tempe              Tempe, AZ
#
#                                 System ID  \
# 0                                     ABU
# 1                             careem_bike
# 2                        bike_buenosaires
# 3                              biketobike
# 4                                movo_bue
# ..                                    ...
# 530  9f74fa80-fb2f-48dc-b2d8-01a889ac008a
# 531  9f74fa80-fb2f-48dc-b2d8-01a889ac008a
# 532  9f74fa80-fb2f-48dc-b2d8-01a889ac008a
# 533  9f74fa80-fb2f-48dc-b2d8-01a889ac008a
# 534  9f74fa80-fb2f-48dc-b2d8-01a889ac008a
#
#                                            URL  \
# 0                    https://www.bikeshare.ae/
# 1    https://www.careem.com/en-ae/careem-bike/
# 2       https://www.buenosaires.gob.ar/ecobici
# 3             https://www.mibicitubici.gob.ar/
# 4                           https://movo.me/ar
# ..                                         ...
# 530                    https://takewheels.com/
# 531                    https://takewheels.com/
# 532                    https://takewheels.com/
# 533                    https://takewheels.com/
# 534                    https://takewheels.com/
#
#                                     Auto-Discovery URL
# 0         https://api-core.bikeshare.ae/gbfs/gbfs.json
# 1      https://dubai.publicbikesystem.net/ube/gbfs/v1/
# 2    https://buenosaires.publicbikesystem.net/ube/g...
# 3    https://www.mibicitubici.gob.ar/opendata/gbfs....
# 4        https://gbfs.movo.me/v1/buenosaires/gbfs.json
# ..                                                 ...
# 530        https://mia-gbfs.getwheelsapp.com/gbfs.json
# 531    https://orlando-gbfs.getwheelsapp.com/gbfs.json
# 532   https://sandiego-gbfs.getwheelsapp.com/gbfs.json
# 533  https://tallahassee-gbfs.getwheelsapp.com/gbfs...
# 534      https://tempe-gbfs.getwheelsapp.com/gbfs.json
#
# [535 rows x 6 columns]

# %%
#getting data from only US cities
us_data=bigdata_df.loc[(bigdata_df["Country Code"]=="US")]
us_data
# Out:
#     Country Code                Name                    Location  \
# 331           US      Austin B-cycle                  Austin, TX
# 332           US     Aventura BCycle                Aventura, FL
# 333           US          Bay Wheels  San Francisco Bay Area, CA
# 334           US    Bike Chattanooga             Chattanooga, TN
# 335           US             BikeLNK                 Lincoln, NE
# ..           ...                 ...                         ...
# 530           US        Wheels Miami                   Miami, FL
# 531           US      Wheels Orlando                 Orlando, FL
# 532           US    Wheels San Diego               San Diego, CA
# 533           US  Wheels Tallahassee             Tallahassee, FL
# 534           US        Wheels Tempe                   Tempe, AZ
#
#                                 System ID                              URL  \
# 331                         bcycle_austin          http://austinbcycle.com
# 332                       bcycle_aventura      https://aventura.bcycle.com
# 333                                    BA       https://www.baywheels.com/
# 334                      bike_chattanooga  http://www.bikechattanooga.com/
# 335                        bcycle_bikelnk       https://bikelnk.bcycle.com
# ..                                    ...                              ...
# 530  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 531  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 532  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 533  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 534  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
#
#                                     Auto-Discovery URL
# 331    https://gbfs.bcycle.com/bcycle_austin/gbfs.json
# 332  https://gbfs.bcycle.com/bcycle_aventura/gbfs.json
# 333          https://gbfs.baywheels.com/gbfs/gbfs.json
# 334     https://chat.publicbikesystem.net/ube/gbfs/v1/
# 335   https://gbfs.bcycle.com/bcycle_bikelnk/gbfs.json
# ..                                                 ...
# 530        https://mia-gbfs.getwheelsapp.com/gbfs.json
# 531    https://orlando-gbfs.getwheelsapp.com/gbfs.json
# 532   https://sandiego-gbfs.getwheelsapp.com/gbfs.json
# 533  https://tallahassee-gbfs.getwheelsapp.com/gbfs...
# 534      https://tempe-gbfs.getwheelsapp.com/gbfs.json
#
# [204 rows x 6 columns]

# %%
#getting data for bird and lime escooter
data_scoot = us_data.loc[us_data['System ID'].str.contains("lime", case=False)]
len(data_scoot)
#data_scoot
data_scoot
# Out:
#     Country Code                Name           Location           System ID  \
# 398           US      Lime Arlington      Arlington, VA      lime_arlington
# 399           US      Lime Baltimore      Baltimore, MD      lime_baltimore
# 400           US        Lime Chicago        Chicago, IL        lime_chicago
# 401           US      Lime Cleveland      Cleveland, OH      lime_cleveland
# 402           US        Lime Detroit        Detroit, MI        lime_detroit
# 403           US     Lime Louisville     Louisville, KY     lime_louisville
# 404           US       Lime New York       New York, NY       lime_new_york
# 405           US        Lime Oakland        Oakland, CA        lime_oakland
# 406           US       Lime Portland       Portland, OR       lime_portland
# 407           US     Lime Providence     Providence, RI     lime_providence
# 408           US  Lime San Francisco  San Francisco, CA  lime_san_francisco
# 409           US        Lime Seattle        Seattle, WA        lime_seattle
# 410           US  Lime Washington DC     Washington, DC  lime_washington_dc
#
#                     URL                                 Auto-Discovery URL
# 398  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/ar...
# 399  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/ba...
# 400  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/ch...
# 401      https://li.me/  https://data.lime.bike/api/partners/v1/gbfs/cl...
# 402  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/de...
# 403  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/lo...
# 404  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/ne...
# 405  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/oa...
# 406  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/po...
# 407   https://www.li.me  https://data.lime.bike/api/partners/v1/gbfs/pr...
# 408       https://li.me  https://data.lime.bike/api/partners/v1/gbfs/sa...
# 409  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/se...
# 410  https://www.li.me/  https://data.lime.bike/api/partners/v1/gbfs/wa...

# %%
##test list of URL
# test_url = ["https://gbfs.spin.pm/api/gbfs/v1/washington_dc/gbfs",
#        "https://gbfs.spin.pm/api/gbfs/v1/san_francisco/gbfs", 
#        "https://gbfs.spin.pm/api/gbfs/v1/tampa/gbfs"]

# %%
# # TESTING HOW ITERROWS WORK - WORKED
# x=1
# for i, row in data_scoot.head(5).iterrows():
# #     unique_id = i
#     city = row['Location']
#     url = row['Auto-Discovery URL']
#     print(city)
#     print(url)
#     x=x+1
# print(x)
# Out:
# Arlington, VA
# https://data.lime.bike/api/partners/v1/gbfs/arlington/gbfs.json
# Baltimore, MD
# https://data.lime.bike/api/partners/v1/gbfs/baltimore/gbfs.json
# Chicago, IL
# https://data.lime.bike/api/partners/v1/gbfs/chicago/gbfs.json
# Cleveland, OH
# https://data.lime.bike/api/partners/v1/gbfs/cleveland/gbfs.json
# Detroit, MI
# https://data.lime.bike/api/partners/v1/gbfs/detroit/gbfs.json
# 6

# %%
# #getting latitudes and longitudes for city as well as coordinates of bird scooters in each cities
# coord_length=[]
lat_list=[]
lon_list=[]
latlon = []
all_url=data_scoot["Auto-Discovery URL"]
x = 0
y = 0
bike = 0
city_list = []
dict = {}
city_list_coord = []
count_list = []
for i, row in data_scoot.iterrows():
        
    try:
        # print(base_url)
        base_url= row['Auto-Discovery URL']
        cities = row['Location']
        print(f'running record {x} on {cities}')

        # get URL for location
        result = requests.get(base_url).json()
        result
        # Fixed the jsondecode issue
        #response = requests.get(base_url).json()
        # print(json.dumps(response, indent=4, sort_keys=True))


        # get URL with bike status for location
        base_url1 = result['data']['en']['feeds'][3]['url']
        base_url1

        # get file with location info
        result1 = requests.get(base_url1).json()
        result1

        bike_coord = result1['data']['bikes']
        bike_coord
        print(f'there are {len(bike_coord)} bikes in record {x}')
        city_list.append(cities)
        count_list.append(len(bike_coord))
        
        for bike in bike_coord:

            # Add Lat info to list
            lat = [bike][0]['lat']
            lon = [bike][0]['lon']
            stripped_lat = lat.strip('')
            stripped_lon = lon.strip('')
    #         print(stripped_lat)
    #         print(stripped_lon)
            lat_list.append(float(stripped_lat))
            lon_list.append(float(stripped_lon))
            city_list_coord.append(cities)

    except ValueError:
        print("Decoding JSON has failed - no bike available")
        city_list.append(cities)
        count_list.append(0)
        
    x = x+1
    time.sleep(2)
# Out:
# running record 0 on Arlington, VA
# there are 304 bikes in record 0
# running record 1 on Baltimore, MD
# there are 492 bikes in record 1
# running record 2 on Chicago, IL
# there are 0 bikes in record 2
# running record 3 on Cleveland, OH
# Decoding JSON has failed - no bike available
# running record 4 on Detroit, MI
# Decoding JSON has failed - no bike available
# running record 5 on Louisville, KY
# Decoding JSON has failed - no bike available
# running record 6 on New York, NY
# there are 367 bikes in record 6
# running record 7 on Oakland, CA
# there are 0 bikes in record 7
# running record 8 on Portland, OR
# there are 564 bikes in record 8
# running record 9 on Providence, RI
# there are 0 bikes in record 9
# running record 10 on San Francisco, CA
# there are 1128 bikes in record 10
# running record 11 on Seattle, WA
# Decoding JSON has failed - no bike available
# running record 12 on Washington, DC
# Decoding JSON has failed - no bike available

# %%
df1 = pd.DataFrame({'City': city_list, 'Count':count_list})
df2 = pd.DataFrame({'Lat':lat_list, 'Lon': lon_list, 'City': city_list_coord})
df['Operator'] = "Lime"
today = date.today()
df['Date'] = today
print(len(lat_list))
print(len(city_list_coord))
print(len(lon_list))
print(len(city_list))
print(len(count_list))
# Out:
# 2855
# 2855
# 2855
# 13
# 13

# %%
df1
# Out:
#                  City  Count
# 0       Arlington, VA    304
# 1       Baltimore, MD    492
# 2         Chicago, IL      0
# 3       Cleveland, OH      0
# 4         Detroit, MI      0
# 5      Louisville, KY      0
# 6        New York, NY    367
# 7         Oakland, CA      0
# 8        Portland, OR    564
# 9      Providence, RI      0
# 10  San Francisco, CA   1128
# 11        Seattle, WA      0
# 12     Washington, DC      0

# %%
lat_list = []
lon_list = [] 

for x in df1["City"]:
    # Target city
    target_city = x
    
    # Build the endpoint URL
    target_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={target_city}&key={gkey}"

    geo_data = requests.get(target_url).json()

    # Extract latitude and longitude
    lat_list.append(geo_data["results"][0]["geometry"]["location"]["lat"])
    lon_list.append(geo_data["results"][0]["geometry"]["location"]["lng"])
# Out:
# Arlington, VA
# Baltimore, MD
# Chicago, IL
# Cleveland, OH
# Detroit, MI
# Louisville, KY
# New York, NY
# Oakland, CA
# Portland, OR
# Providence, RI
# San Francisco, CA
# Seattle, WA
# Washington, DC

# %%
df1["lat"] = lat_list
df1['lon']= lon_list
df1['Operator'] = "Lime"
today = date.today()
df1['Date'] = today
df1.to_csv('Lime_Lat_Lon.csv')

# %%
locations = list(zip(lat_list,lon_list))
locations
# Out:
# [(38.8642, -77.0411),
#  (38.8629, -77.0435),
#  (38.863, -77.0435),
#  (38.8499, -77.0436),
#  (38.8521, -77.0437),
#  (38.8673, -77.0452),
#  (38.8538, -77.0459),
#  (38.8538, -77.0462),
#  (38.8482, -77.0467),
#  (38.8697, -77.0473),
#  (38.8599, -77.0492),
#  (38.8523, -77.0526),
#  (38.845, -77.0487),
#  (38.8529, -77.0491),
#  (38.8598, -77.0492),
#  (41.502, -81.6936),
#  (41.5018, -81.6938),
#  (41.5018, -81.6938),
#  (41.5013, -81.6939),
#  (41.502, -81.6941),
#  (41.5018, -81.6943),
#  (41.504, -81.6943),
#  (41.4992, -81.6944),
#  (41.5038, -81.6946),
#  (41.5034, -81.6946),
#  (41.5041, -81.6947),
#  (41.4999, -81.6947),
#  (41.5032, -81.6948),
#  (41.5029, -81.6949),
#  (41.4998, -81.695),
#  (41.498, -81.695),
#  (41.477, -81.6952),
#  (41.4771, -81.6952),
#  (41.477, -81.6952),
#  (41.4996, -81.6954),
#  (41.5034, -81.6957),
#  (41.5002, -81.6961),
#  (41.5009, -81.6962),
#  (41.5009, -81.6965),
#  (41.5006, -81.6966),
#  (41.5025, -81.6967),
#  (41.5004, -81.6968),
#  (41.5029, -81.6969),
#  (41.5002, -81.6969),
#  (41.5007, -81.6969),
#  (41.4981, -81.697),
#  (41.5006, -81.697),
#  (41.5002, -81.697),
#  (41.5007, -81.697),
#  (41.5029, -81.6971),
#  (41.5014, -81.6974),
#  (41.5017, -81.6977),
#  (41.5002, -81.6978),
#  (41.5, -81.6979),
#  (41.4995, -81.6981),
#  (41.4993, -81.6983),
#  (41.5012, -81.6984),
#  (41.4956, -81.6985),
#  (41.4996, -81.6987),
#  (41.495, -81.6987),
#  (41.5026, -81.6988),
#  (41.5027, -81.6988),
#  (41.5026, -81.6989),
#  (41.5003, -81.6991),
#  (41.5007, -81.6992),
#  (41.5003, -81.6994),
#  (41.4697, -81.6994),
#  (41.5007, -81.6995),
#  (41.501, -81.6996),
#  (41.5018, -81.6996),
#  (41.5012, -81.6997),
#  (41.5014, -81.6997),
#  (41.5007, -81.6998),
#  (41.5008, -81.6999),
#  (41.501, -81.6999),
#  (41.501, -81.7),
#  (41.5011, -81.7),
#  (41.5011, -81.7001),
#  (41.4988, -81.7002),
#  (41.4986, -81.7002),
#  (41.464, -81.7003),
#  (41.464, -81.7003),
#  (41.4989, -81.7004),
#  (41.4635, -81.7004),
#  (41.4991, -81.7005),
#  (41.4988, -81.7006),
#  (41.4989, -81.7006),
#  (41.4991, -81.7006),
#  (41.4987, -81.7007),
#  (41.4994, -81.7012),
#  (41.5, -81.7013),
#  (41.4995, -81.7013),
#  (41.5005, -81.7015),
#  (41.498, -81.7017),
#  (41.4979, -81.7017),
#  (41.4979, -81.7017),
#  (41.4979, -81.7018),
#  ...]

# %%
#generating the heat map using the city(lat and lon values) with
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, dissipating=False, max_intensity=100,
                                point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#look at google gmaps documentation
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Operator Name</dt><dd>{Operator}</dd>
<dt>City</dt><dd>{City}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
escooter_info = [info_box_template.format(**row) for index, row in df.iterrows()]
locations = df[["Lat", "Lon"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations,
    info_box_content=escooter_info)
fig.add_layer(markers)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
